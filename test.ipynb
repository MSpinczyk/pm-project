# %%
import openai
from openai import OpenAI

# %%
client = OpenAI(api_key='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')

response = client.chat.completions.create(
model="gpt-4",
messages=[
    {
    "role": "system",
    "content": """You will be provided with text description of process model. Generate Spreadsheet represantation of it. Example os spreadshet: 
    Order | Activity | Condition | Who | Input | Output
    0 | start at time | Scheduled Departure | Traffic Department | | 
    1 | Print Traffic Card | | | | Traffic card
    2a1 | Take Car from Stock | | Depot | | 
    2a2 | Wash Car | | | | 
    2a3 | Place Car on Track | | | | 
    2b1 | Await Driver | | Traffic Department | | 
    2b2a | goto 2b3 | Driver arrived | | | 
    2b2b | Call for Driver | else | | | 
    2b3 | Check Alcohol Level | | | | 
    2b4a | Authorize Driver | Alcohol level OK | | | 
    2b4b | goto 2b2b | else | | | 
    3 | Take Car from Track | | Driver | Traffic card | 
    4 | Register Departure | | Traffic Department | | 
    5 | end | Registered Departure | | | """
    },
    {
    "role": "user",
    "content": f"""A customer brings in a defective computer and the
CRS checks the defect and hands out a repair cost
calculation back. If the customer decides that the
costs are acceptable, the process continues, otherwise
she takes her computer home unrepaired. The ongoing
repair consists of two activities, which are executed,
in an arbitrary order. The first activity is to check
and repair the hardware, whereas the second activity
checks and configures the software. After each of
these activities, the proper system functionality
is tested. If an error is detected another arbitrary
repair activity is executed, otherwise the repair is
finished."""
    }
],
temperature=0.7,
max_tokens=512,
top_p=1
)
# Out:
# Running cells with 'c:\Users\micha\anaconda3\envs\pm-project-2\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\micha\anaconda3\envs\pm-project-2 ipykernel --update-deps --force-reinstall'

# %%
response.choices[0].message.content
# Out:
# 'Order | Activity | Condition | Who | Input | Output\n--- | --- | --- | --- | --- | ---\n0 | Start Process | Customer arrives with defective computer | Customer Service Representative (CRS) | Defective Computer | \n1 | Check Defect and Calculate Repair Cost | | CRS | Defective Computer | Repair Cost Calculation\n2a | Customer Accepts Cost | Costs are acceptable | Customer | Repair Cost Calculation | \n2b | Customer Declines Cost and Leaves | Costs not acceptable | Customer | Repair Cost Calculation | Unrepaired Computer\n3a1 | Check and Repair Hardware | If process continues after 2a | Technician | Defective Computer | Repaired Hardware\n3a2 | Test System Functionality | After 3a1 | Technician | Repaired Hardware | Test Results\n3b1 | Check and Configure Software | If process continues after 2a | Technician | Defective Computer | Configured Software\n3b2 | Test System Functionality | After 3b1 | Technician | Configured Software | Test Results\n4a | Repair Hardware (again) | If error detected in 3a2 | Technician | Defective Computer | Repaired Hardware (again)\n4b | Configure Software (again) | If error detected in 3b2 | Technician | Defective Computer | Configured Software (again)\n5 | End Process | If no error detected after 3a2 and 3b2 or 4a and 4b | | | Repaired Computer'

# %%
client = OpenAI(api_key='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')

response = client.chat.completions.create(
model="gpt-4",
messages=[
    {
    "role": "system",
    "content": """You will be provided with text description of process model. Generate a table represantation of it. Columns: 
    Order Activity Condition Who Input Output"""
    },
    {
    "role": "user",
    "content": f"""A customer brings in a defective computer and the
CRS checks the defect and hands out a repair cost
calculation back. If the customer decides that the
costs are acceptable, the process continues, otherwise
she takes her computer home unrepaired. The ongoing
repair consists of two activities, which are executed,
in an arbitrary order. The first activity is to check
and repair the hardware, whereas the second activity
checks and configures the software. After each of
these activities, the proper system functionality
is tested. If an error is detected another arbitrary
repair activity is executed, otherwise the repair is
finished."""
    }
],
temperature=0.7,
max_tokens=512,
top_p=1
)

# %%
response.choices[0].message.content
# Out:
# '| Order | Activity                                      | Condition                                                | Who      | Input                | Output                    |\n|-------|-----------------------------------------------|-----------------------------------------------------------|----------|----------------------|--------------------------|\n| 1     | Check the defect                              | Customer brings in a defective computer                   | CRS      | Defective computer   | Repair cost calculation  |\n| 2     | Hand out a repair cost calculation            | Defect checked                                            | CRS      | Defective computer   | Repair cost calculation  |\n| 3     | Decide if costs are acceptable                | Received repair cost calculation                          | Customer | Repair cost          | Decision                  |\n| 4     | Take computer home unrepaired                 | Costs are not acceptable                                  | Customer | Defective computer   | Unrepaired computer      |\n| 5     | Check and repair the hardware                 | Costs are acceptable and repair process continues        | CRS      | Defective computer   | Repaired hardware        |\n| 6     | Check and configure the software              | Costs are acceptable and repair process continues        | CRS      | Defective computer   | Configured software      |\n| 7     | Test system functionality after hardware fix  | Hardware has been repaired                                | CRS      | Repaired hardware    | Functionality test result|\n| 8     | Test system functionality after software fix  | Software has been configured                              | CRS      | Configured software  | Functionality test result|\n| 9     | Execute another arbitrary repair activity     | An error is detected in functionality test               | CRS      | Defective computer   | Repaired computer        |\n| 10    | Finish repair                                 | No error is detected in functionality test               | CRS      | Repaired computer    | Repaired computer        |'

# %%
import sys
sys.path.append('src')
from spreadsheet_processing import create_spreadsheet

create_spreadsheet(response.choices[0].message.content)#.to_csv('test.csv', index=False)
# Out:
#    Order   Activity                                        \
# 1  1       Check the defect
# 2  2       Hand out a repair cost calculation
# 3  3       Decide if costs are acceptable
# 4  4       Take computer home unrepaired
# 5  5       Check and repair the hardware
# 6  6       Check and configure the software
# 7  7       Test system functionality after hardware fix
# 8  8       Test system functionality after software fix
# 9  9       Execute another arbitrary repair activity
#
#   Condition                                                  Who        \
# 1  Customer brings in a defective computer       ...         CRS
# 2  Defect checked                                ...         CRS
# 3  Received repair cost calculation              ...         Customer
# 4  Costs are not acceptable                      ...         Customer
# 5  Costs are acceptable and repair process contin...         CRS
# 6  Costs are acceptable and repair process contin...         CRS
# 7  Hardware has been repaired                    ...         CRS
# 8  Software has been configured                  ...         CRS
# 9  An error is detected in functionality test    ...         CRS
#
#    Input                  Output
# 1  Defective computer      Repair cost calculation
# 2  Defective computer      Repair cost calculation
# 3  Repair cost            Decision
# 4  Defective computer      Unrepaired computer
# 5  Defective computer      Repaired hardware
# 6  Defective computer      Configured software
# 7  Repaired hardware       Functionality test result
# 8  Configured software     Functionality test result
# 9  Defective computer      Repaired computer

# %%
import pandas as pd
from io import StringIO

# %%
df = pd.read_csv('test.csv', index_col=None)
df
# Out:
#    Order   Activity                                        \
# 0       1  Check the defect
# 1       2  Hand out a repair cost calculation
# 2       3  Decide if costs are acceptable
# 3       4  Take computer home unrepaired
# 4       5  Check and repair the hardware
# 5       6  Check and configure the software
# 6       7  Test system functionality after hardware fix
# 7       8  Test system functionality after software fix
# 8       9  Execute another arbitrary repair activity
#
#   Condition                                                  Who        \
# 0  Customer brings in a defective computer       ...         CRS
# 1  Defect checked                                ...         CRS
# 2  Received repair cost calculation              ...         Customer
# 3  Costs are not acceptable                      ...         Customer
# 4  Costs are acceptable and repair process contin...         CRS
# 5  Costs are acceptable and repair process contin...         CRS
# 6  Hardware has been repaired                    ...         CRS
# 7  Software has been configured                  ...         CRS
# 8  An error is detected in functionality test    ...         CRS
#
#    Input                  Output
# 0  Defective computer      Repair cost calculation
# 1  Defective computer      Repair cost calculation
# 2  Repair cost            Decision
# 3  Defective computer      Unrepaired computer
# 4  Defective computer      Repaired hardware
# 5  Defective computer      Configured software
# 6  Repaired hardware       Functionality test result
# 7  Configured software     Functionality test result
# 8  Defective computer      Repaired computer

# %%
data = StringIO(response.choices[0].message.content)

# Read the data into a DataFrame
df = pd.read_csv(data, sep='|', skipinitialspace=True)

# Display the DataFrame
df
# Out:
#    Order                                 Activity   \
# 0    ---                                      ---
# 1      0                            Start Process
# 2      1   Check Defect and Calculate Repair Cost
# 3     2a                    Customer Accepts Cost
# 4     2b        Customer Declines Cost and Leaves
# 5    3a1                Check and Repair Hardware
# 6    3a2                Test System Functionality
# 7    3b1             Check and Configure Software
# 8    3b2                Test System Functionality
# 9     4a                  Repair Hardware (again)
# 10    4b               Configure Software (again)
# 11     5                              End Process
#
#                                            Condition   \
# 0                                                ---
# 1           Customer arrives with defective computer
# 2                                                 NaN
# 3                               Costs are acceptable
# 4                               Costs not acceptable
# 5                      If process continues after 2a
# 6                                          After 3a1
# 7                      If process continues after 2a
# 8                                          After 3b1
# 9                           If error detected in 3a2
# 10                          If error detected in 3b2
# 11  If no error detected after 3a2 and 3b2 or 4a a...
#
#                                       Who                     Input   \
# 0                                     ---                       ---
# 1   Customer Service Representative (CRS)        Defective Computer
# 2                                     CRS        Defective Computer
# 3                                Customer   Repair Cost Calculation
# 4                                Customer   Repair Cost Calculation
# 5                              Technician        Defective Computer
# 6                              Technician         Repaired Hardware
# 7                              Technician        Defective Computer
# 8                              Technician       Configured Software
# 9                              Technician        Defective Computer
# 10                             Technician        Defective Computer
# 11                                     NaN                       NaN
#
#                          Output
# 0                           ---
# 1                           NaN
# 2       Repair Cost Calculation
# 3                           NaN
# 4           Unrepaired Computer
# 5             Repaired Hardware
# 6                  Test Results
# 7           Configured Software
# 8                  Test Results
# 9     Repaired Hardware (again)
# 10  Configured Software (again)
# 11            Repaired Computer

# %%
from bpmn_python.bpmn_process_csv_import import BpmnDiagramGraph, BpmnDiagramGraphCSVImport

# Create an instance of BpmnDiagramGraph
bpmn_diagram = BpmnDiagramGraph()

# Specify the path to your CSV file
csv_filepath = 'path/to/your/csv/file.csv'

# Load the BPMN diagram from the CSV file
BpmnDiagramGraphCSVImport.load_diagram_from_csv(csv_filepath, bpmn_diagram)

# Now, bpmn_diagram contains the BPMN diagram loaded from the CSV file
# Out:
# Running cells with 'c:\Users\micha\anaconda3\envs\pm-project-2\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\micha\anaconda3\envs\pm-project-2 ipykernel --update-deps --force-reinstall'
